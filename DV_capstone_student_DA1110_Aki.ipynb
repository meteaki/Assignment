# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df0 = pd.read_csv('store_sharing.csv')
df = df0
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
# Out:
#              timestamp  cnt   t1  ...  is_holiday  is_weekend  season
# 0  2015-01-04 00:00:00  182  3.0  ...         0.0         1.0     3.0
# 1  2015-01-04 01:00:00  138  3.0  ...         0.0         1.0     3.0
# 2  2015-01-04 02:00:00  134  2.5  ...         0.0         1.0     3.0
# 3  2015-01-04 03:00:00   72  2.0  ...         0.0         1.0     3.0
# 4  2015-01-04 04:00:00   47  2.0  ...         0.0         1.0     3.0
#
# [5 rows x 10 columns]

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.isna().count()
# Out:
# timestamp       17414
# cnt             17414
# t1              17414
# t2              17414
# hum             17414
# wind_speed      17414
# weather_code    17414
# is_holiday      17414
# is_weekend      17414
# season          17414
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
# Out:
# False    17414
# dtype: int64

# %%
df.isna().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
df.head(1)
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0

# %%
df['season'].value_counts().index
# Out:
# Float64Index([0.0, 1.0, 3.0, 2.0], dtype='float64')

# %%
fig, ax = plt.subplots()
sns.countplot(df['season']);

# %%
# season

# %%
df.head(1)
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0

# %%
df['is_holiday'].value_counts().values
# Out:
# array([17030,   384], dtype=int64)

# %%
df['is_holiday'].value_counts().index
# Out:
# Float64Index([0.0, 1.0], dtype='float64')

# %%
fig, ax = plt.subplots()

sns.countplot(df['is_holiday']);

# %%
# is_holiday

# %%
fig, ax = plt.subplots()

sns.countplot(df['is_weekend']);

# %%
# is_weekend

# %%
df['weather_code'].value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
fig, ax = plt.subplots()

sns.countplot(df['weather_code']);

# %%
# weather_code

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.head(1)
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0

# %%
type(df['timestamp'][0])
# Out:
# str

# %%
df1 = df.set_index('timestamp').copy()
df1
# Out:
#                       cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0
# ...                         ...         ...     ...
# 2017-01-03 19:00:00         0.0         0.0     3.0
# 2017-01-03 20:00:00         0.0         0.0     3.0
# 2017-01-03 21:00:00         0.0         0.0     3.0
# 2017-01-03 22:00:00         0.0         0.0     3.0
# 2017-01-03 23:00:00         0.0         0.0     3.0
#
# [17414 rows x 9 columns]

# %%
# Out:
#                      cnt   t1   t2  ...  is_holiday  is_weekend  season
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 01:00:00  138  3.0  2.5  ...         0.0         1.0     3.0
# 2015-01-04 02:00:00  134  2.5  2.5  ...         0.0         1.0     3.0
# 2015-01-04 03:00:00   72  2.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 04:00:00   47  2.0  0.0  ...         0.0         1.0     3.0
#
# [5 rows x 9 columns]

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
date = df1.index
date
# Out:
# Index(['2015-01-04 00:00:00', '2015-01-04 01:00:00', '2015-01-04 02:00:00',
#        '2015-01-04 03:00:00', '2015-01-04 04:00:00', '2015-01-04 05:00:00',
#        '2015-01-04 06:00:00', '2015-01-04 07:00:00', '2015-01-04 08:00:00',
#        '2015-01-04 09:00:00',
#        ...
#        '2017-01-03 14:00:00', '2017-01-03 15:00:00', '2017-01-03 16:00:00',
#        '2017-01-03 17:00:00', '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#        '2017-01-03 20:00:00', '2017-01-03 21:00:00', '2017-01-03 22:00:00',
#        '2017-01-03 23:00:00'],
#       dtype='object', name='timestamp', length=17414)

# %%
datetime_format = pd.to_datetime(date)
datetime_format
# Out:
# DatetimeIndex(['2015-01-04 00:00:00', '2015-01-04 01:00:00',
#                '2015-01-04 02:00:00', '2015-01-04 03:00:00',
#                '2015-01-04 04:00:00', '2015-01-04 05:00:00',
#                '2015-01-04 06:00:00', '2015-01-04 07:00:00',
#                '2015-01-04 08:00:00', '2015-01-04 09:00:00',
#                ...
#                '2017-01-03 14:00:00', '2017-01-03 15:00:00',
#                '2017-01-03 16:00:00', '2017-01-03 17:00:00',
#                '2017-01-03 18:00:00', '2017-01-03 19:00:00',
#                '2017-01-03 20:00:00', '2017-01-03 21:00:00',
#                '2017-01-03 22:00:00', '2017-01-03 23:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=17414, freq=None)

# %%
df1['date'] = datetime_format

# %%
df1['year_month'] = datetime_format.strftime("%Y-%m")

# %%
df1['year'] = df1['date'].dt.year

# %%
df1['month'] = df1['date'].dt.month

# %%
df1['day_of_month'] = df1['date'].dt.day

# %%
df1['day_of_week'] = df1['date'].dt.weekday

# %%
df1['hour'] = df1['date'].dt.hour

# %%
df1.drop('date', axis=1, inplace=True)

# %%
df1.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# 2015-01-04 00:00:00             4            6     0
# 2015-01-04 01:00:00             4            6     1
# 2015-01-04 02:00:00             4            6     2
# 2015-01-04 03:00:00             4            6     3
# 2015-01-04 04:00:00             4            6     4

# %%
# Out:
#                      cnt   t1   t2  ...  day_of_month  day_of_week  hour
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...             4            6     0
# 2015-01-04 01:00:00  138  3.0  2.5  ...             4            6     1
# 2015-01-04 02:00:00  134  2.5  2.5  ...             4            6     2
# 2015-01-04 03:00:00   72  2.0  2.0  ...             4            6     3
# 2015-01-04 04:00:00   47  2.0  0.0  ...             4            6     4
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17414 entries, 2015-01-04 00:00:00 to 2017-01-03 23:00:00
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cnt           17414 non-null  int64
#  1   t1            17414 non-null  float64
#  2   t2            17414 non-null  float64
#  3   hum           17414 non-null  float64
#  4   wind_speed    17414 non-null  float64
#  5   weather_code  17414 non-null  float64
#  6   is_holiday    17414 non-null  float64
#  7   is_weekend    17414 non-null  float64
#  8   season        17414 non-null  float64
#  9   year_month    17414 non-null  object
#  10  year          17414 non-null  int64
#  11  month         17414 non-null  int64
#  12  day_of_month  17414 non-null  int64
#  13  day_of_week   17414 non-null  int64
#  14  hour          17414 non-null  int64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 2.6+ MB

# %%
# Out:
#                    cnt        t1        t2       hum  wind_speed  \
# cnt           1.000000  0.388798  0.369035 -0.462901    0.116295
# t1            0.388798  1.000000  0.988344 -0.447781    0.145471
# t2            0.369035  0.988344  1.000000 -0.403495    0.088409
# hum          -0.462901 -0.447781 -0.403495  1.000000   -0.287789
# wind_speed    0.116295  0.145471  0.088409 -0.287789    1.000000
# weather_code -0.166633 -0.097114 -0.098385  0.334750    0.124803
# is_holiday   -0.051698 -0.042233 -0.040051  0.032068   -0.002606
# is_weekend   -0.096499 -0.005342 -0.008510  0.028098    0.011479
# season       -0.116180 -0.285851 -0.285900  0.290381    0.010305
# year          0.010046 -0.037959 -0.044972  0.072443   -0.094739
# month         0.063757  0.332712  0.368366  0.113149   -0.086383
# day_of_month -0.017887  0.005072  0.006791 -0.020868    0.002040
# day_of_week  -0.068688 -0.002317 -0.006824  0.011556    0.001708
# hour          0.324423  0.168708  0.153956 -0.295653    0.141792
#
#               weather_code  is_holiday  is_weekend    season      year  \
# cnt              -0.166633   -0.051698   -0.096499 -0.116180  0.010046
# t1               -0.097114   -0.042233   -0.005342 -0.285851 -0.037959
# t2               -0.098385   -0.040051   -0.008510 -0.285900 -0.044972
# hum               0.334750    0.032068    0.028098  0.290381  0.072443
# wind_speed        0.124803   -0.002606    0.011479  0.010305 -0.094739
# weather_code      1.000000    0.012939    0.042362  0.098976 -0.009234
# is_holiday        0.012939    1.000000   -0.094898 -0.032488  0.034631
# is_weekend        0.042362   -0.094898    1.000000  0.001067  0.003049
# season            0.098976   -0.032488    0.001067  1.000000  0.024400
# year             -0.009234    0.034631    0.003049  0.024400  1.000000
# month            -0.033253   -0.011511   -0.005406  0.203249 -0.026547
# day_of_month      0.001904    0.042657    0.005721 -0.006460 -0.021935
# day_of_week       0.020619   -0.144628    0.791975  0.002356 -0.002876
# hour             -0.041786   -0.000288    0.001803  0.000006  0.000542
#
#                  month  day_of_month  day_of_week      hour
# cnt           0.063757     -0.017887    -0.068688  0.324423
# t1            0.332712      0.005072    -0.002317  0.168708
# t2            0.368366      0.006791    -0.006824  0.153956
# hum           0.113149     -0.020868     0.011556 -0.295653
# wind_speed   -0.086383      0.002040     0.001708  0.141792
# weather_code -0.033253      0.001904     0.020619 -0.041786
# is_holiday   -0.011511      0.042657    -0.144628 -0.000288
# is_weekend   -0.005406      0.005721     0.791975  0.001803
# season        0.203249     -0.006460     0.002356  0.000006
# year         -0.026547     -0.021935    -0.002876  0.000542
# month         1.000000      0.012614    -0.001080 -0.000312
# day_of_month  0.012614      1.000000     0.006974 -0.000310
# day_of_week  -0.001080      0.006974     1.000000  0.001834
# hour         -0.000312     -0.000310     0.001834  1.000000

# %%
fig, ax = plt.subplots(figsize = (16,12))
sns.heatmap(df1.corr(), annot=True, cmap='Blues');

# %%
# for all variables

# %%
fig, ax = plt.subplots(figsize = (2,10))
corr = df1.corr()
x = corr[['cnt']]
sns.heatmap(x, annot=True, cmap='Blues');

# %%
# for the target variable

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
fig, ax = plt.subplots(figsize = (10,6))
corr = df1.corr()
x1 = corr[['cnt']].sort_values(by='cnt')
ax.barh(x1.index, x1['cnt']);

# %%
#with pandas

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
fig, ax = plt.subplots(figsize = (12,4))

ax.bar(df1['date'], df1['cnt']);

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
fig, ax=plt.subplots(figsize=(20, 6))
ax = sns.lineplot(df1['year_month'], df1['cnt'], ci=None)

plt.xticks(rotation=90);
# Out:
# ''

# %%
# with lineplot

# %%
fig, ax=plt.subplots(figsize=(10, 6))

sns.lineplot(df1['month'], df1['cnt']);

# %%
# with lineplot

# %%
fig, ax=plt.subplots(figsize=(15, 5))
ax.set_xticklabels(df1['month'])
sns.pointplot(df1['month'], df1['cnt']);

# %%
# with pointplot

# %%
fig, ax=plt.subplots(figsize=(10, 6))
ax.set_xticklabels(df1['month'])
sns.barplot(df1['month'], df1['cnt']);

# %%
# with barplot

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
fig, plt.subplots(figsize=(18,4))

sns.lineplot('hour', 'cnt', data=df1, hue = 'is_holiday')

plt.legend(title='is_holiday');

# %%
# with lineplot (*whether it is a holiday or not*)

# %%
fig, plt.subplots(figsize=(15,4))

sns.lineplot('hour', 'cnt', data=df1, hue='season')


plt.legend(sorted(df1['season'].unique()), title='season');

# %%
# with lineplot (*You may want to see seasonal breakdowns*)

# %%
fig, ax = plt.subplots(4, 1, figsize =(18,12))

sns.pointplot('hour', 'cnt', ax = ax[0], data=df1)

sns.pointplot('hour', 'cnt', ax = ax[1], data=df1, hue = 'is_holiday')

sns.pointplot('hour', 'cnt', ax = ax[2], data=df1, hue = 'is_weekend')

sns.pointplot('hour', 'cnt', ax = ax[3], data=df1, hue='season');

# %%
# with pointplot

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
fig, plt.subplots(figsize =(7,4))

sns.barplot('day_of_week', 'cnt', data=df1, hue='is_weekend');

# %%
# with barplot

# %%
fig, ax = plt.subplots(2,1, figsize =(15,6))

sns.pointplot('day_of_week', 'cnt', data=df1, ax=ax[0])

sns.pointplot('day_of_week', 'cnt', data=df1, ax=ax[1], hue='season');

# %%
# with pointplot

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
fig, plt.subplots(figsize =(15,5))

sns.lineplot('day_of_month', 'cnt', data=df1);

# %%
#with lineplot
# Out:
# day_of_month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1128  1144  1141  ...  1131  1063  1080  1156  968
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
fig, plt.subplots(figsize =(10,6))


sns.barplot('year', 'cnt', data=df1);

# %%
# with barplot

# %%
fig, plt.subplots(figsize =(6,4))
df_h = df1[df1['is_holiday'] == 1]
sns.barplot('season', 'cnt', data=df_h);

# %%
# with barplot

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df1['is_weekend'].value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6, 6))

ax.pie(x=df1['is_weekend'].value_counts().values, labeldistance=1.1, autopct='%.1f%%', startangle=0);

# %%
# pie chart

# %%
values = df1['is_weekend'].value_counts()
values
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
percentage = (df1['is_weekend'].value_counts(normalize=True)*100).round(1).values
percentage
# Out:
# array([71.5, 28.5])

# %%
fig, ax = plt.subplots(figsize =(7,5))
graph = sns.countplot(df1['is_weekend'], ax= ax)

i=0
for p in graph.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2.0, p.get_height() + 1,
        ('%' + str(percentage[i]) + ' - ' + (str(values[i]))), ha="center", size=13)
    i += 1

plt.show()

# %%
# with countplot

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
df1['weather_code'].value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
df1['season'].value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
fig, ax = plt.subplots(figsize =(6,4))
sns.countplot(df1['weather_code'], ax= ax);

# %%
# with countplot

# %%
df_s0 = df1[df1['season'] == 0]['weather_code']
df_s1 = df1[df1['season'] == 1]['weather_code']
df_s2 = df1[df1['season'] == 2]['weather_code']
df_s3 = df1[df1['season'] == 3]['weather_code']

# %%
fig, ax = plt.subplots(1, 4, figsize =(24,6),sharex=True, sharey=True)

sns.countplot(df_s0, ax= ax[0])
sns.countplot(df_s1, ax= ax[1])
sns.countplot(df_s2, ax= ax[2])
sns.countplot(df_s3, ax= ax[3])

ax[0].set_title('season = 0.0')
ax[1].set_title('season = 1.0')
ax[2].set_title('season = 2.0')
ax[3].set_title('season = 3.0');

# %%
# with catplot

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
